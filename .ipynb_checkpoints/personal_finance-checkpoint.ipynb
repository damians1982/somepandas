# %%
import pandas as pd

# %%
#import pliku z aplikacji monefy

# %%
df = pd.read_csv('finance_data/monefy-2022-12-14_03-07-14_ALL.csv')

# %%
#wrzucenie danych do pliku excel
#df.to_excel('finance_data/excelled.xlsx', sheet_name='koszty')

# %%
df
# Out:
#             date account       category   amount currency  converted amount  \
# 0      8/31/2021    Cash          Bills -1500.00      THB          -1500.00
# 1       9/2/2021    Cash           Food  -614.55      THB           -614.55
# 2       9/2/2021    Cash           Food  -108.26      THB           -108.26
# 3       9/2/2021    Cash  Entertainment  -311.63      THB           -311.63
# 4       9/2/2021    Cash  Entertainment  -200.53      THB           -200.53
# ...          ...     ...            ...      ...      ...               ...
# 2202  12/13/2022    Cash           Food  -490.00      THB           -490.00
# 2203  12/13/2022    Cash         Health  -560.00      THB           -560.00
# 2204  12/13/2022    Cash          Bills  -100.00      THB           -100.00
# 2205  12/14/2022    Cash  Entertainment  -510.00      THB           -510.00
# 2206  12/14/2022    Cash           Food  -100.00      THB           -100.00
#
#      currency.1               description
# ...

# %%
print(type(df['date'][0]))
# Out:
# <class 'str'>

# %%
df['description'][2202]
# Out:
# 'Indyjska kohinor'

# %%
df[ (df['amount'] > -1000) & (df['amount'] < -600)]
# Out:
#             date account       category  amount currency  converted amount  \
# 1       9/2/2021    Cash           Food -614.55      THB           -614.55
# 98     9/29/2021    Cash         Health -750.00      THB           -750.00
# 463   12/24/2021    Cash  Entertainment -650.00      THB           -650.00
# 1471    7/7/2022    Cash          Gifts -700.00      THB           -700.00
# 1931  10/18/2022    Cash           Food -710.00      THB           -710.00
# 1972  10/27/2022    Cash         Health -750.00      THB           -750.00
# 1980  10/29/2022    Cash           Food -690.00      THB           -690.00
# 2056  11/14/2022    Cash         Health -800.00      THB           -800.00
# 2086  11/19/2022    Cash           Food -650.00      THB           -650.00
# 2111  11/25/2022    Cash         Health -800.00      THB           -800.00
# 2135  11/29/2022    Cash  Entertainment -900.00      THB           -900.00
# ...

# %%
#df.groupby('category').sum()
